# %%
import openai as OpenAI
import os
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 import openai as OpenAI
#       2 import os
# ----> 3 client = OpenAI()
#
# TypeError: 'module' object is not callable

# %%
client = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 client = OpenAI()
#
# TypeError: 'module' object is not callable

# %%
resp = client.responses.create(
    model="gpt-4.1-mini",
    input="Say hello in one sentence."
)
print(resp.output_text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 resp = client.responses.create(
#       2     model="gpt-4.1-mini",
#       3     input="Say hello in one sentence."
#       4 )
#       5 print(resp.output_text)
#
# NameError: name 'client' is not defined

# %%
client = OpenAI()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 client = OpenAI()
#
# TypeError: 'module' object is not callable
